# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/home/kiran/Downloads/eda/Raw-Data/ADIDatabase_2015.csv')

# %%
df
# Out:
#       Unnamed: 0          Vessel                         RefNO  \
# 0             60     KAILASH GAS          ADI/KAILA/2015/Apr/4
# 1             87  FALCON VICTORY          ADI/VICTO/2015/Jul/2
# 2            133   CALA PINGUINO            ADI/PIN/2015/Nov/6
# 3            134    EAST BANGKOK  ADI/BANGK-SMPL-C/2015/Nov/27
# 4            135    EAST BANGKOK  ADI/BANGK-SMPL-C/2015/Nov/28
# ...          ...             ...                           ...
# 1406        1600   MAERSK EDIRNE           ADI/MEDN/2020/May/1
# 1407        1601  SOUTHERN GLORY           ADI/SOGL/2020/May/1
# 1408        1602   LOWLANDS BLUE           ADI/LLBL/2020/May/2
# 1409        1603  VELOS SAPPHIRE           ADI/VESA/2020/May/4
# 1410        1604       BW KIZOKU           ADI/BWKI/2020/Jun/1
#
#                OccurrenceDate               ReportDate Defect Status Location  \
# 0     2015-04-13 09:15:51.000  2015-04-13 04:02:44.533        Closed      Sea
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate',
#        'Defect Status', 'Location', 'Port', 'IncidentDetails',
#        'IncidentEventDetails', 'ImmediateAction', 'Incident Category',
#        'Possibility Recurrence', 'AreaOfConcern',
#        'DetailedExtentofDamageInjury', 'DirectCause', 'IndirectCause',
#        'RootCause', 'Proposedcorrectiveactions', 'Corrective Action',
#        'LeariningPotential', 'SeverityOfIncident', 'RevisedIncidentCategory',
#        'Cause Analysis', 'Accident Details', 'LessionLearnt', 'ReviewComments',
#        'ClosingNote', 'ClosingDate', 'Injured Person Name',
#        'Injured Person Rank', 'OtherRank', 'OtherUser',
#        'InjuryAccidentCategory', 'Injured Part', 'Other Part'],
#       dtype='str')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'IndirectCause', 'RootCause', 'Proposedcorrectiveactions',
#        'Corrective Action', 'LeariningPotential', 'SeverityOfIncident',
#        'RevisedIncidentCategory', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ReviewComments', 'ClosingNote', 'ClosingDate',
#        'Injured Person Name', 'Injured Person Rank', 'OtherRank', 'OtherUser',
#        'InjuryAccidentCategory', 'Injured Part', 'Other Part'],
#       dtype='str')

# %%
df.describe()
# Out:
#        IndirectCause  RootCause
# count            0.0        0.0
# mean             NaN        NaN
# std              NaN        NaN
# min              NaN        NaN
# 25%              NaN        NaN
# 50%              NaN        NaN
# 75%              NaN        NaN
# max              NaN        NaN

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1411 entries, 0 to 1410
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Vessel                        1411 non-null   str
#  1   RefNO                         1411 non-null   str
#  2   OccurrenceDate                1411 non-null   str
#  3   ReportDate                    1411 non-null   str
#  4   Defect Status                 1411 non-null   str
#  5   Location                      1411 non-null   str
#  6   Port                          345 non-null    str
#  7   IncidentDetails               1405 non-null   str
#  8   IncidentEventDetails          1288 non-null   str
#  9   ImmediateAction               1389 non-null   str
#  10  Incident Category             1411 non-null   str
#  11  Possibility Recurrence        1388 non-null   str
#  12  AreaOfConcern                 1228 non-null   str
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# IndirectCause                   1411
# RootCause                       1411
# RevisedIncidentCategory         1369
# Other Part                      1336
# Injured Person Name             1216
# ReviewComments                  1126
# Port                            1066
# Injured Person Rank             1012
# LessionLearnt                    996
# Injured Part                     925
# Accident Details                 916
# InjuryAccidentCategory           849
# OtherRank                        841
# OtherUser                        840
# Corrective Action                591
# DirectCause                      330
# LeariningPotential               304
# DetailedExtentofDamageInjury     206
# ClosingDate                      205
# AreaOfConcern                    183
# SeverityOfIncident               175
# ClosingNote                      164
# IncidentEventDetails             123
# Proposedcorrectiveactions         59
# Possibility Recurrence            23
# ...

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Vessel                            0.000000
# RefNO                             0.000000
# OccurrenceDate                    0.000000
# ReportDate                        0.000000
# Defect Status                     0.000000
# Location                          0.000000
# Port                             75.549256
# IncidentDetails                   0.425230
# IncidentEventDetails              8.717222
# ImmediateAction                   1.559178
# Incident Category                 0.000000
# Possibility Recurrence            1.630050
# AreaOfConcern                    12.969525
# DetailedExtentofDamageInjury     14.599575
# DirectCause                      23.387668
# IndirectCause                   100.000000
# RootCause                       100.000000
# Proposedcorrectiveactions         4.181432
# Corrective Action                41.885188
# LeariningPotential               21.545004
# SeverityOfIncident               12.402551
# RevisedIncidentCategory          97.023388
# ...

# %%
df['OccurrenceDate'] = pd.to_datetime(df['OccurrenceDate'], errors='coerce')
df['ReportDate'] = pd.to_datetime(df['ReportDate'], errors='coerce')
df['ClosingDate'] = pd.to_datetime(df['ClosingDate'], errors='coerce')

# %%
df['year'] = df['OccurrenceDate'].dt.year
df['month'] = df['OccurrenceDate'].dt.month

# %%
import matplotlib.pyplot as plt

df['year'].value_counts().sort_index().plot(kind='bar')
plt.title("Incidents per Year")
plt.show()

# %%
df['month'].value_counts().sort_index().plot(kind='bar')
plt.title("Incidents per Month")
plt.show()

# %%
df['Port'].value_counts().head(10)
# Out:
# Port
# SINGAPORE       18
# ANTWERP          7
# ZHOUSHAN         6
# HOUSTON          6
# NEW ORLEANS      6
# ROTTERDAM        5
# QINGDAO          5
# PANAMA CANAL     5
# NINGBO           5
# PORT KLANG       4
# Name: count, dtype: int64

# %%
df['Port'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Ports with Incidents")
plt.show()

# %%
df['Incident Category'].value_counts()
# Out:
# Incident Category
# Minor                                911
# Marginal Or Moderate Harm            445
# Critical Or Severe Harm               41
# Catastrophic Or Extremely Harmful     14
# Name: count, dtype: int64

# %%
df['Incident Category'].value_counts().plot(kind='bar')
plt.title("Incident Categories")
plt.show()

# %%
df['SeverityOfIncident'].value_counts()
# Out:
# SeverityOfIncident
# Medium    580
# Low       496
# High      160
# Name: count, dtype: int64

# %%
df['SeverityOfIncident'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Severity Distribution")
plt.show()

# %%
df['RootCause'].value_counts().head(10)
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['Vessel'].value_counts().head(10)
# Out:
# Vessel
# COMPASS           20
# APL CALIFORNIA    19
# SRI VISHNU        19
# COMPASSION        18
# NAVE PULSAR       18
# NAVE EQUINOX      17
# JBU SAPPHIRE      17
# SEROJA ENAM       17
# JBU OPAL          16
# SOLAR N           16
# Name: count, dtype: int64

# %%
df['Vessel'].value_counts().head(10).plot(kind='bar')
plt.title("Vessels with Most Incidents")
plt.show()

# %%
df['Injured Part'].value_counts().head(10)
# Out:
# Injured Part
# Finger      172
# Leg          83
# Back         49
# Eye          35
# Wrist        31
# Face         29
# Forehead     26
# Skull        16
# Shoulder     16
# Toe          13
# Name: count, dtype: int64

# %%
df['InjuryAccidentCategory'].value_counts()
# Out:
# InjuryAccidentCategory
# First aid case                  241
# Medical treatment case          144
# Lost Workday Case                91
# Restricted work case             42
# Fatality                         39
# Permanent partial disability      4
# Permanent total disability        1
# Name: count, dtype: int64

# %%
df['Possibility Recurrence'].value_counts()
# Out:
# Possibility Recurrence
# Unlikely         590
# Likely           341
# Very Unlikely    310
# Very Likely      147
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'IndirectCause', 'RootCause', 'Proposedcorrectiveactions',
#        'Corrective Action', 'LeariningPotential', 'SeverityOfIncident',
#        'RevisedIncidentCategory', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ReviewComments', 'ClosingNote', 'ClosingDate',
#        'Injured Person Name', 'Injured Person Rank', 'OtherRank', 'OtherUser',
#        'InjuryAccidentCategory', 'Injured Part', 'Other Part', 'year',
#        'month'],
#       dtype='str')

# %%
df.drop(columns=['DirectCause'],inplace=True)

# %%
df.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'IndirectCause',
#        'RootCause', 'Proposedcorrectiveactions', 'Corrective Action',
#        'LeariningPotential', 'SeverityOfIncident', 'RevisedIncidentCategory',
#        'Cause Analysis', 'Accident Details', 'LessionLearnt', 'ReviewComments',
#        'ClosingNote', 'ClosingDate', 'Injured Person Name',
#        'Injured Person Rank', 'OtherRank', 'OtherUser',
#        'InjuryAccidentCategory', 'Injured Part', 'Other Part', 'year',
#        'month'],
#       dtype='str')

# %%
df.drop(columns=['IndirectCause'],inplace=True)

# %%
df.drop(columns=['RootCause'] , inplace=True)

# %%
df.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury',
#        'Proposedcorrectiveactions', 'Corrective Action', 'LeariningPotential',
#        'SeverityOfIncident', 'RevisedIncidentCategory', 'Cause Analysis',
#        'Accident Details', 'LessionLearnt', 'ReviewComments', 'ClosingNote',
#        'ClosingDate', 'Injured Person Name', 'Injured Person Rank',
#        'OtherRank', 'OtherUser', 'InjuryAccidentCategory', 'Injured Part',
#        'Other Part', 'year', 'month'],
#       dtype='str')

# %%
import seaborn as sns

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df['OccurrenceDate'].dt.year.value_counts().sort_index()
# Out:
# OccurrenceDate
# 2015     51
# 2016    211
# 2017    296
# 2018    313
# 2019    357
# 2020    183
# Name: count, dtype: int64
